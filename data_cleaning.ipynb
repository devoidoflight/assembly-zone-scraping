# %%
import json
import os
import pandas as pd
from summarytools import dfSummary

# %%
import os
import pandas as pd
import chardet

csv_files = []

for file in os.listdir('./results'):
    filepath = os.path.join('./results', file)
    try:
        # Detect encoding
        with open(filepath, 'rb') as f:
            raw_data = f.read()
            result = chardet.detect(raw_data)
            encoding = result['encoding']
        
        # Read the file with detected encoding
        df = pd.read_csv(filepath, encoding=encoding)
        csv_files.append(df)
    except Exception as e:
        print(f"Could not process {file}: {e}")
# Out:
# Could not process .DS_Store: Error tokenizing data. C error: Expected 3 fields in line 17, saw 6

# %%
df = pd.concat(csv_files, ignore_index=True)

df.head()
# Out:
# /var/folders/hw/l074dk897h96d7rpk3q148pr0000gn/T/ipykernel_27603/3454373427.py:1: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat(csv_files, ignore_index=True)
#                                            tesis_adi    il_adi  \
# 0                                      HÜNKAR ÇAYIRI   KOCAELİ
# 1  Şehit Ertan Bayraktar Parkı ( Aynı Zamanda TRA...  İSTANBUL
# 2                        Şehit Er Sezgin Zorba Parkı  İSTANBUL
# 3                         Mareşal Fevzi Çakmak Parkı  İSTANBUL
# 4                                   Yunus Emre Parkı  İSTANBUL
#
#         sokak_adi ilce_adi mahalle_adi        lng        lat         id  \
# 0           2257.    GEBZE  CUMHURİYET  29.342166  40.828265   63185581
# 1     ŞİFA YANYOL    TUZLA        ŞİFA  29.342166  40.828265  151349528
# 2     ŞİFA YANYOL    TUZLA        ŞİFA  29.342166  40.828265  151349526
# 3  D-100 KARAYOLU    TUZLA    İSTASYON  29.338605  40.830061  151349569
# 4  D-100 KARAYOLU    TUZLA    İSTASYON  29.338605  40.830061  151349572
#
#                                       polygon_bounds
# 0  POLYGON ((29.346930219 40.819681165, 29.343153...
# 1  POLYGON ((29.354165322 40.823642472, 29.353916...
# 2  POLYGON ((29.354554688 40.828230434, 29.354698...
# 3  POLYGON ((29.323768052 40.824934154, 29.324463...
# 4  POLYGON ((29.323840301 40.827228783, 29.323797...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33424 entries, 0 to 33423
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tesis_adi       33424 non-null  object
#  1   il_adi          33424 non-null  object
#  2   sokak_adi       33421 non-null  object
#  3   ilce_adi        33424 non-null  object
#  4   mahalle_adi     33424 non-null  object
#  5   lng             33424 non-null  float64
#  6   lat             33424 non-null  float64
#  7   id              33424 non-null  object
#  8   polygon_bounds  33130 non-null  object
# dtypes: float64(2), object(7)
# memory usage: 2.3+ MB

# %%
df.describe()
# Out:
#                 lng           lat
# count  33424.000000  33424.000000
# mean      28.953670     41.033815
# std        0.278482      0.084225
# min       27.979736     40.805399
# 25%       28.800129     40.994165
# 50%       28.974039     41.026612
# 75%       29.157738     41.070933
# max       29.946482     41.493252

# %%
dfSummary(df)
# Out:
# <style type="text/css">
# #T_67e63 thead>tr>th {
#   text-align: left;
# }
# #T_67e63_row0_col0, #T_67e63_row1_col0, #T_67e63_row2_col0, #T_67e63_row3_col0, #T_67e63_row4_col0, #T_67e63_row5_col0, #T_67e63_row6_col0, #T_67e63_row7_col0, #T_67e63_row8_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_67e63_row0_col1, #T_67e63_row1_col1, #T_67e63_row2_col1, #T_67e63_row3_col1, #T_67e63_row4_col1, #T_67e63_row5_col1, #T_67e63_row6_col1, #T_67e63_row7_col1, #T_67e63_row8_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_67e63_row0_col2, #T_67e63_row1_col2, #T_67e63_row2_col2, #T_67e63_row3_col2, #T_67e63_row4_col2, #T_67e63_row5_col2, #T_67e63_row6_col2, #T_67e63_row7_col2, #T_67e63_row8_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_67e63_row0_col3, #T_67e63_row1_col3, #T_67e63_row2_col3, #T_67e63_row3_col3, #T_67e63_row4_col3, #T_67e63_row5_col3, #T_67e63_row6_col3, #T_67e63_row7_col3, #T_67e63_row8_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
#   min-width: 100px;
# }
# #T_67e63_row0_col4, #T_67e63_row1_col4, #T_67e63_row2_col4, #T_67e63_row3_col4, #T_67e63_row4_col4, #T_67e63_row5_col4, #T_67e63_row6_col4, #T_67e63_row7_col4, #T_67e63_row8_col4 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 20%;
#   min-width: 150px;
# }
# #T_67e63_row0_col5, #T_67e63_row1_col5, #T_67e63_row2_col5, #T_67e63_row3_col5, #T_67e63_row4_col5, #T_67e63_row5_col5, #T_67e63_row6_col5, #T_67e63_row7_col5, #T_67e63_row8_col5 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 10%;
# }
# </style>
# <table id="T_67e63">
#   <caption><strong>Data Frame Summary</strong><br>df<br>Dimensions: 33,424 x 9<br>Duplicates: 11,894</caption>
#   <thead>
#     <tr>
#       <th id="T_67e63_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_67e63_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_67e63_level0_col2" class="col_heading level0 col2" >Stats / Values</th>
#       <th id="T_67e63_level0_col3" class="col_heading level0 col3" >Freqs / (% of Valid)</th>
#       <th id="T_67e63_level0_col4" class="col_heading level0 col4" >Graph</th>
#       <th id="T_67e63_level0_col5" class="col_heading level0 col5" >Missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_67e63_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_67e63_row0_col1" class="data row0 col1" ><strong>tesis_adi</strong><br>[object]</td>
#       <td id="T_67e63_row0_col2" class="data row0 col2" >1. Cumhuriyet Parkı<br>2. Atatürk Parkı<br>3. Fatih Sultan Mehmet Parkı<br>4. Mehmet Akif Ersoy Parkı<br>5. Yunus Emre Parkı<br>6. Adnan Menderes Parkı<br>7. Aşık Veysel Parkı<br>8. Lale Parkı<br>9. Mimar Sinan Parkı<br>10. Mevlana Parkı<br>11. other</td>
#       <td id="T_67e63_row0_col3" class="data row0 col3" >144 (0.4%)<br>102 (0.3%)<br>76 (0.2%)<br>71 (0.2%)<br>57 (0.2%)<br>55 (0.2%)<br>54 (0.2%)<br>52 (0.2%)<br>50 (0.1%)<br>49 (0.1%)<br>32,714 (97.9%)</td>
#       <td id="T_67e63_row0_col4" class="data row0 col4" ><img src = "......"></img></td>
#       <td id="T_67e63_row0_col5" class="data row0 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_67e63_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_67e63_row1_col1" class="data row1 col1" ><strong>il_adi</strong><br>[object]</td>
#       <td id="T_67e63_row1_col2" class="data row1 col2" >1. İSTANBUL<br>2. KOCAELİ<br>3. KIRKLARELİ<br>4. TEKİRDAĞ</td>
#       <td id="T_67e63_row1_col3" class="data row1 col3" >33,326 (99.7%)<br>40 (0.1%)<br>39 (0.1%)<br>19 (0.1%)</td>
#       <td id="T_67e63_row1_col4" class="data row1 col4" ><img src = "......"></img></td>
#       <td id="T_67e63_row1_col5" class="data row1 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_67e63_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_67e63_row2_col1" class="data row2 col1" ><strong>sokak_adi</strong><br>[object]</td>
#       <td id="T_67e63_row2_col2" class="data row2 col2" >1. ATATÜRK<br>2. TURGUT ÖZAL<br>3. ESKİ EDİRNE ASFALTI<br>4. FATİH<br>5. ŞİLE YOLU<br>6. CUMHURİYET<br>7. İNÖNÜ<br>8. DEMOKRASİ<br>9. MEHMET AKİF ERSOY<br>10. ADNAN KAHVECİ<br>11. other</td>
#       <td id="T_67e63_row2_col3" class="data row2 col3" >401 (1.2%)<br>301 (0.9%)<br>250 (0.7%)<br>244 (0.7%)<br>221 (0.7%)<br>219 (0.7%)<br>207 (0.6%)<br>182 (0.5%)<br>150 (0.4%)<br>145 (0.4%)<br>31,104 (93.1%)</td>
#       <td id="T_67e63_row2_col4" class="data row2 col4" ><img src = "......"></img></td>
#       <td id="T_67e63_row2_col5" class="data row2 col5" >3<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_67e63_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_67e63_row3_col1" class="data row3 col1" ><strong>ilce_adi</strong><br>[object]</td>
#       <td id="T_67e63_row3_col2" class="data row3 col2" >1. BAĞCILAR<br>2. PENDİK<br>3. KÜÇÜKÇEKMECE<br>4. ÜMRANİYE<br>5. ÇEKMEKÖY<br>6. ESENYURT<br>7. SİLİVRİ<br>8. ÜSKÜDAR<br>9. BEYKOZ<br>10. SANCAKTEPE<br>11. other</td>
#       <td id="T_67e63_row3_col3" class="data row3 col3" >1,675 (5.0%)<br>1,553 (4.6%)<br>1,475 (4.4%)<br>1,402 (4.2%)<br>1,379 (4.1%)<br>1,333 (4.0%)<br>1,261 (3.8%)<br>1,257 (3.8%)<br>1,249 (3.7%)<br>1,190 (3.6%)<br>19,650 (58.8%)</td>
#       <td id="T_67e63_row3_col4" class="data row3 col4" ><img src = "......"></img></td>
#       <td id="T_67e63_row3_col5" class="data row3 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_67e63_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_67e63_row4_col1" class="data row4 col1" ><strong>mahalle_adi</strong><br>[object]</td>
#       <td id="T_67e63_row4_col2" class="data row4 col2" >1. CUMHURİYET<br>2. MERKEZ<br>3. FATİH<br>4. ATATÜRK<br>5. MİMAR SİNAN<br>6. HÜRRİYET<br>7. FEVZİ ÇAKMAK<br>8. YENİ MAHALLE<br>9. HAMİDİYE<br>10. BAHÇELİEVLER<br>11. other</td>
#       <td id="T_67e63_row4_col3" class="data row4 col3" >1,555 (4.7%)<br>960 (2.9%)<br>916 (2.7%)<br>781 (2.3%)<br>614 (1.8%)<br>580 (1.7%)<br>520 (1.6%)<br>364 (1.1%)<br>359 (1.1%)<br>355 (1.1%)<br>26,420 (79.0%)</td>
#       <td id="T_67e63_row4_col4" class="data row4 col4" ><img src = "......"></img></td>
#       <td id="T_67e63_row4_col5" class="data row4 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_67e63_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_67e63_row5_col1" class="data row5 col1" ><strong>lng</strong><br>[float64]</td>
#       <td id="T_67e63_row5_col2" class="data row5 col2" >Mean (sd) : 29.0 (0.3)<br>min < med < max:<br>28.0 < 29.0 < 29.9<br>IQR (CV) : 0.4 (104.0)</td>
#       <td id="T_67e63_row5_col3" class="data row5 col3" >15,713 distinct values</td>
#       <td id="T_67e63_row5_col4" class="data row5 col4" ><img src = "......"></img></td>
#       <td id="T_67e63_row5_col5" class="data row5 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_67e63_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_67e63_row6_col1" class="data row6 col1" ><strong>lat</strong><br>[float64]</td>
#       <td id="T_67e63_row6_col2" class="data row6 col2" >Mean (sd) : 41.0 (0.1)<br>min < med < max:<br>40.8 < 41.0 < 41.5<br>IQR (CV) : 0.1 (487.2)</td>
#       <td id="T_67e63_row6_col3" class="data row6 col3" >8,858 distinct values</td>
#       <td id="T_67e63_row6_col4" class="data row6 col4" ><img src = "......"></img></td>
#       <td id="T_67e63_row6_col5" class="data row6 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_67e63_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_67e63_row7_col1" class="data row7 col1" ><strong>id</strong><br>[object]</td>
#       <td id="T_67e63_row7_col2" class="data row7 col2" >1. 151346907<br>2. 151346979<br>3. 151346921<br>4. 151346922<br>5. 151346909<br>6. 151346923<br>7. 151347487<br>8. 151350050<br>9. 151350125<br>10. 151349915<br>11. other</td>
#       <td id="T_67e63_row7_col3" class="data row7 col3" >37 (0.1%)<br>37 (0.1

# %%
df = df.drop_duplicates(keep='first')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21530 entries, 0 to 33423
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tesis_adi       21530 non-null  object
#  1   il_adi          21530 non-null  object
#  2   sokak_adi       21527 non-null  object
#  3   ilce_adi        21530 non-null  object
#  4   mahalle_adi     21530 non-null  object
#  5   lng             21530 non-null  float64
#  6   lat             21530 non-null  float64
#  7   id              21530 non-null  object
#  8   polygon_bounds  21327 non-null  object
# dtypes: float64(2), object(7)
# memory usage: 1.6+ MB

# %%
df.describe()
# Out:
#                 lng           lat
# count  21530.000000  21530.000000
# mean      28.962564     41.035551
# std        0.281153      0.085954
# min       27.979736     40.805399
# 25%       28.814604     40.993256
# 50%       28.978087     41.027566
# 75%       29.157509     41.074812
# max       29.946482     41.493252

# %%
dfSummary(df)
# Out:
# <style type="text/css">
# #T_e49fa thead>tr>th {
#   text-align: left;
# }
# #T_e49fa_row0_col0, #T_e49fa_row1_col0, #T_e49fa_row2_col0, #T_e49fa_row3_col0, #T_e49fa_row4_col0, #T_e49fa_row5_col0, #T_e49fa_row6_col0, #T_e49fa_row7_col0, #T_e49fa_row8_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_e49fa_row0_col1, #T_e49fa_row1_col1, #T_e49fa_row2_col1, #T_e49fa_row3_col1, #T_e49fa_row4_col1, #T_e49fa_row5_col1, #T_e49fa_row6_col1, #T_e49fa_row7_col1, #T_e49fa_row8_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_e49fa_row0_col2, #T_e49fa_row1_col2, #T_e49fa_row2_col2, #T_e49fa_row3_col2, #T_e49fa_row4_col2, #T_e49fa_row5_col2, #T_e49fa_row6_col2, #T_e49fa_row7_col2, #T_e49fa_row8_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_e49fa_row0_col3, #T_e49fa_row1_col3, #T_e49fa_row2_col3, #T_e49fa_row3_col3, #T_e49fa_row4_col3, #T_e49fa_row5_col3, #T_e49fa_row6_col3, #T_e49fa_row7_col3, #T_e49fa_row8_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
#   min-width: 100px;
# }
# #T_e49fa_row0_col4, #T_e49fa_row1_col4, #T_e49fa_row2_col4, #T_e49fa_row3_col4, #T_e49fa_row4_col4, #T_e49fa_row5_col4, #T_e49fa_row6_col4, #T_e49fa_row7_col4, #T_e49fa_row8_col4 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 20%;
#   min-width: 150px;
# }
# #T_e49fa_row0_col5, #T_e49fa_row1_col5, #T_e49fa_row2_col5, #T_e49fa_row3_col5, #T_e49fa_row4_col5, #T_e49fa_row5_col5, #T_e49fa_row6_col5, #T_e49fa_row7_col5, #T_e49fa_row8_col5 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 10%;
# }
# </style>
# <table id="T_e49fa">
#   <caption><strong>Data Frame Summary</strong><br>df<br>Dimensions: 21,530 x 9<br>Duplicates: 0</caption>
#   <thead>
#     <tr>
#       <th id="T_e49fa_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_e49fa_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_e49fa_level0_col2" class="col_heading level0 col2" >Stats / Values</th>
#       <th id="T_e49fa_level0_col3" class="col_heading level0 col3" >Freqs / (% of Valid)</th>
#       <th id="T_e49fa_level0_col4" class="col_heading level0 col4" >Graph</th>
#       <th id="T_e49fa_level0_col5" class="col_heading level0 col5" >Missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e49fa_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_e49fa_row0_col1" class="data row0 col1" ><strong>tesis_adi</strong><br>[object]</td>
#       <td id="T_e49fa_row0_col2" class="data row0 col2" >1. Cumhuriyet Parkı<br>2. Atatürk Parkı<br>3. Mehmet Akif Ersoy Parkı<br>4. Yunus Emre Parkı<br>5. Fatih Sultan Mehmet Parkı<br>6. Aşık Veysel Parkı<br>7. Mimar Sinan Parkı<br>8. Mevlana Parkı<br>9. Kardelen Parkı<br>10. Necip Fazıl Kısakürek Parkı<br>11. other</td>
#       <td id="T_e49fa_row0_col3" class="data row0 col3" >73 (0.3%)<br>61 (0.3%)<br>50 (0.2%)<br>42 (0.2%)<br>34 (0.2%)<br>32 (0.1%)<br>31 (0.1%)<br>29 (0.1%)<br>29 (0.1%)<br>29 (0.1%)<br>21,120 (98.1%)</td>
#       <td id="T_e49fa_row0_col4" class="data row0 col4" ><img src = "......"></img></td>
#       <td id="T_e49fa_row0_col5" class="data row0 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_e49fa_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_e49fa_row1_col1" class="data row1 col1" ><strong>il_adi</strong><br>[object]</td>
#       <td id="T_e49fa_row1_col2" class="data row1 col2" >1. İSTANBUL<br>2. KOCAELİ<br>3. TEKİRDAĞ<br>4. KIRKLARELİ</td>
#       <td id="T_e49fa_row1_col3" class="data row1 col3" >21,461 (99.7%)<br>40 (0.2%)<br>19 (0.1%)<br>10 (0.0%)</td>
#       <td id="T_e49fa_row1_col4" class="data row1 col4" ><img src = "......"></img></td>
#       <td id="T_e49fa_row1_col5" class="data row1 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_e49fa_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_e49fa_row2_col1" class="data row2 col1" ><strong>sokak_adi</strong><br>[object]</td>
#       <td id="T_e49fa_row2_col2" class="data row2 col2" >1. ATATÜRK<br>2. ESKİ EDİRNE ASFALTI<br>3. TURGUT ÖZAL<br>4. ŞİLE YOLU<br>5. MEHMET AKİF ERSOY<br>6. FATİH<br>7. İNÖNÜ<br>8. İSTANBUL<br>9. CUMHURİYET<br>10. DEMOKRASİ<br>11. other</td>
#       <td id="T_e49fa_row2_col3" class="data row2 col3" >245 (1.1%)<br>185 (0.9%)<br>140 (0.7%)<br>140 (0.7%)<br>107 (0.5%)<br>104 (0.5%)<br>99 (0.5%)<br>98 (0.5%)<br>98 (0.5%)<br>89 (0.4%)<br>20,225 (93.9%)</td>
#       <td id="T_e49fa_row2_col4" class="data row2 col4" ><img src = "......"></img></td>
#       <td id="T_e49fa_row2_col5" class="data row2 col5" >3<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_e49fa_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_e49fa_row3_col1" class="data row3 col1" ><strong>ilce_adi</strong><br>[object]</td>
#       <td id="T_e49fa_row3_col2" class="data row3 col2" >1. PENDİK<br>2. ÜMRANİYE<br>3. BAĞCILAR<br>4. ARNAVUTKÖY<br>5. ÜSKÜDAR<br>6. KÜÇÜKÇEKMECE<br>7. BEYKOZ<br>8. ESENYURT<br>9. SARIYER<br>10. ÇEKMEKÖY<br>11. other</td>
#       <td id="T_e49fa_row3_col3" class="data row3 col3" >998 (4.6%)<br>942 (4.4%)<br>856 (4.0%)<br>816 (3.8%)<br>813 (3.8%)<br>807 (3.7%)<br>784 (3.6%)<br>762 (3.5%)<br>760 (3.5%)<br>742 (3.4%)<br>13,250 (61.5%)</td>
#       <td id="T_e49fa_row3_col4" class="data row3 col4" ><img src = "......"></img></td>
#       <td id="T_e49fa_row3_col5" class="data row3 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_e49fa_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_e49fa_row4_col1" class="data row4 col1" ><strong>mahalle_adi</strong><br>[object]</td>
#       <td id="T_e49fa_row4_col2" class="data row4 col2" >1. CUMHURİYET<br>2. MERKEZ<br>3. ATATÜRK<br>4. MİMAR SİNAN<br>5. FATİH<br>6. FEVZİ ÇAKMAK<br>7. HÜRRİYET<br>8. ATAKENT<br>9. BAHÇELİEVLER<br>10. HAMİDİYE<br>11. other</td>
#       <td id="T_e49fa_row4_col3" class="data row4 col3" >603 (2.8%)<br>445 (2.1%)<br>353 (1.6%)<br>347 (1.6%)<br>327 (1.5%)<br>267 (1.2%)<br>246 (1.1%)<br>237 (1.1%)<br>220 (1.0%)<br>199 (0.9%)<br>18,286 (84.9%)</td>
#       <td id="T_e49fa_row4_col4" class="data row4 col4" ><img src = "......"></img></td>
#       <td id="T_e49fa_row4_col5" class="data row4 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_e49fa_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_e49fa_row5_col1" class="data row5 col1" ><strong>lng</strong><br>[float64]</td>
#       <td id="T_e49fa_row5_col2" class="data row5 col2" >Mean (sd) : 29.0 (0.3)<br>min < med < max:<br>28.0 < 29.0 < 29.9<br>IQR (CV) : 0.3 (103.0)</td>
#       <td id="T_e49fa_row5_col3" class="data row5 col3" >15,713 distinct values</td>
#       <td id="T_e49fa_row5_col4" class="data row5 col4" ><img src = "......"></img></td>
#       <td id="T_e49fa_row5_col5" class="data row5 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_e49fa_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_e49fa_row6_col1" class="data row6 col1" ><strong>lat</strong><br>[float64]</td>
#       <td id="T_e49fa_row6_col2" class="data row6 col2" >Mean (sd) : 41.0 (0.1)<br>min < med < max:<br>40.8 < 41.0 < 41.5<br>IQR (CV) : 0.1 (477.4)</td>
#       <td id="T_e49fa_row6_col3" class="data row6 col3" >8,858 distinct values</td>
#       <td id="T_e49fa_row6_col4" class="data row6 col4" ><img src = "......"></img></td>
#       <td id="T_e49fa_row6_col5" class="data row6 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_e49fa_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_e49fa_row7_col1" class="data row7 col1" ><strong>id</strong><br>[object]</td>
#       <td id="T_e49fa_row7_col2" class="data row7 col2" >1. 151347398<br>2. 151347487<br>3. 151346922<br>4. 151349178<br>5. 151346921<br>6. 151347081<br>7. 151346895<br>8. 151349209<br>9. 151349034<br>10. 151349573<br>11. other</td>
#       <td id="T_e49fa_row7_col3" class="data row7 col3" >16 (0.1%)<br>16 (0.1%)<br>15 (0.1%)<br>15 (0.1%)<br>

# %%
df = df[df['il_adi']=='İSTANBUL']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21461 entries, 1 to 33423
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tesis_adi       21461 non-null  object
#  1   il_adi          21461 non-null  object
#  2   sokak_adi       21458 non-null  object
#  3   ilce_adi        21461 non-null  object
#  4   mahalle_adi     21461 non-null  object
#  5   lng             21461 non-null  float64
#  6   lat             21461 non-null  float64
#  7   id              21461 non-null  object
#  8   polygon_bounds  21260 non-null  object
# dtypes: float64(2), object(7)
# memory usage: 1.6+ MB

# %%
df.describe()
# Out:
#                 lng           lat
# count  21461.000000  21461.000000
# mean      28.962775     41.035398
# std        0.278563      0.085192
# min       27.979736     40.805399
# 25%       28.814892     40.993403
# 50%       28.978040     41.027566
# 75%       29.156680     41.074703
# max       29.946482     41.448469

# %%
dfSummary(df)
# Out:
# <style type="text/css">
# #T_76082 thead>tr>th {
#   text-align: left;
# }
# #T_76082_row0_col0, #T_76082_row1_col0, #T_76082_row2_col0, #T_76082_row3_col0, #T_76082_row4_col0, #T_76082_row5_col0, #T_76082_row6_col0, #T_76082_row7_col0, #T_76082_row8_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_76082_row0_col1, #T_76082_row1_col1, #T_76082_row2_col1, #T_76082_row3_col1, #T_76082_row4_col1, #T_76082_row5_col1, #T_76082_row6_col1, #T_76082_row7_col1, #T_76082_row8_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_76082_row0_col2, #T_76082_row1_col2, #T_76082_row2_col2, #T_76082_row3_col2, #T_76082_row4_col2, #T_76082_row5_col2, #T_76082_row6_col2, #T_76082_row7_col2, #T_76082_row8_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_76082_row0_col3, #T_76082_row1_col3, #T_76082_row2_col3, #T_76082_row3_col3, #T_76082_row4_col3, #T_76082_row5_col3, #T_76082_row6_col3, #T_76082_row7_col3, #T_76082_row8_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
#   min-width: 100px;
# }
# #T_76082_row0_col4, #T_76082_row1_col4, #T_76082_row2_col4, #T_76082_row3_col4, #T_76082_row4_col4, #T_76082_row5_col4, #T_76082_row6_col4, #T_76082_row7_col4, #T_76082_row8_col4 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 20%;
#   min-width: 150px;
# }
# #T_76082_row0_col5, #T_76082_row1_col5, #T_76082_row2_col5, #T_76082_row3_col5, #T_76082_row4_col5, #T_76082_row5_col5, #T_76082_row6_col5, #T_76082_row7_col5, #T_76082_row8_col5 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 10%;
# }
# </style>
# <table id="T_76082">
#   <caption><strong>Data Frame Summary</strong><br>df<br>Dimensions: 21,461 x 9<br>Duplicates: 0</caption>
#   <thead>
#     <tr>
#       <th id="T_76082_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_76082_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_76082_level0_col2" class="col_heading level0 col2" >Stats / Values</th>
#       <th id="T_76082_level0_col3" class="col_heading level0 col3" >Freqs / (% of Valid)</th>
#       <th id="T_76082_level0_col4" class="col_heading level0 col4" >Graph</th>
#       <th id="T_76082_level0_col5" class="col_heading level0 col5" >Missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_76082_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_76082_row0_col1" class="data row0 col1" ><strong>tesis_adi</strong><br>[object]</td>
#       <td id="T_76082_row0_col2" class="data row0 col2" >1. Cumhuriyet Parkı<br>2. Atatürk Parkı<br>3. Mehmet Akif Ersoy Parkı<br>4. Yunus Emre Parkı<br>5. Fatih Sultan Mehmet Parkı<br>6. Aşık Veysel Parkı<br>7. Mimar Sinan Parkı<br>8. Necip Fazıl Kısakürek Parkı<br>9. Mevlana Parkı<br>10. Kardelen Parkı<br>11. other</td>
#       <td id="T_76082_row0_col3" class="data row0 col3" >73 (0.3%)<br>55 (0.3%)<br>50 (0.2%)<br>42 (0.2%)<br>34 (0.2%)<br>32 (0.1%)<br>31 (0.1%)<br>29 (0.1%)<br>29 (0.1%)<br>29 (0.1%)<br>21,057 (98.1%)</td>
#       <td id="T_76082_row0_col4" class="data row0 col4" ><img src = "......"></img></td>
#       <td id="T_76082_row0_col5" class="data row0 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_76082_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_76082_row1_col1" class="data row1 col1" ><strong>il_adi</strong><br>[object]</td>
#       <td id="T_76082_row1_col2" class="data row1 col2" >1. İSTANBUL</td>
#       <td id="T_76082_row1_col3" class="data row1 col3" >21,461 (100.0%)</td>
#       <td id="T_76082_row1_col4" class="data row1 col4" ><img src = "......"></img></td>
#       <td id="T_76082_row1_col5" class="data row1 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_76082_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_76082_row2_col1" class="data row2 col1" ><strong>sokak_adi</strong><br>[object]</td>
#       <td id="T_76082_row2_col2" class="data row2 col2" >1. ATATÜRK<br>2. ESKİ EDİRNE ASFALTI<br>3. ŞİLE YOLU<br>4. TURGUT ÖZAL<br>5. MEHMET AKİF ERSOY<br>6. FATİH<br>7. İNÖNÜ<br>8. İSTANBUL<br>9. CUMHURİYET<br>10. DEMOKRASİ<br>11. other</td>
#       <td id="T_76082_row2_col3" class="data row2 col3" >245 (1.1%)<br>185 (0.9%)<br>140 (0.7%)<br>137 (0.6%)<br>107 (0.5%)<br>104 (0.5%)<br>99 (0.5%)<br>98 (0.5%)<br>98 (0.5%)<br>89 (0.4%)<br>20,159 (93.9%)</td>
#       <td id="T_76082_row2_col4" class="data row2 col4" ><img src = "......"></img></td>
#       <td id="T_76082_row2_col5" class="data row2 col5" >3<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_76082_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_76082_row3_col1" class="data row3 col1" ><strong>ilce_adi</strong><br>[object]</td>
#       <td id="T_76082_row3_col2" class="data row3 col2" >1. PENDİK<br>2. ÜMRANİYE<br>3. BAĞCILAR<br>4. ARNAVUTKÖY<br>5. ÜSKÜDAR<br>6. KÜÇÜKÇEKMECE<br>7. BEYKOZ<br>8. ESENYURT<br>9. SARIYER<br>10. ÇEKMEKÖY<br>11. other</td>
#       <td id="T_76082_row3_col3" class="data row3 col3" >998 (4.7%)<br>942 (4.4%)<br>856 (4.0%)<br>816 (3.8%)<br>813 (3.8%)<br>807 (3.8%)<br>784 (3.7%)<br>762 (3.6%)<br>760 (3.5%)<br>742 (3.5%)<br>13,181 (61.4%)</td>
#       <td id="T_76082_row3_col4" class="data row3 col4" ><img src = "......"></img></td>
#       <td id="T_76082_row3_col5" class="data row3 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_76082_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_76082_row4_col1" class="data row4 col1" ><strong>mahalle_adi</strong><br>[object]</td>
#       <td id="T_76082_row4_col2" class="data row4 col2" >1. CUMHURİYET<br>2. MERKEZ<br>3. ATATÜRK<br>4. MİMAR SİNAN<br>5. FATİH<br>6. FEVZİ ÇAKMAK<br>7. HÜRRİYET<br>8. ATAKENT<br>9. BAHÇELİEVLER<br>10. HAMİDİYE<br>11. other</td>
#       <td id="T_76082_row4_col3" class="data row4 col3" >584 (2.7%)<br>445 (2.1%)<br>353 (1.6%)<br>347 (1.6%)<br>327 (1.5%)<br>267 (1.2%)<br>246 (1.1%)<br>237 (1.1%)<br>220 (1.0%)<br>199 (0.9%)<br>18,236 (85.0%)</td>
#       <td id="T_76082_row4_col4" class="data row4 col4" ><img src = "......"></img></td>
#       <td id="T_76082_row4_col5" class="data row4 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_76082_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_76082_row5_col1" class="data row5 col1" ><strong>lng</strong><br>[float64]</td>
#       <td id="T_76082_row5_col2" class="data row5 col2" >Mean (sd) : 29.0 (0.3)<br>min < med < max:<br>28.0 < 29.0 < 29.9<br>IQR (CV) : 0.3 (104.0)</td>
#       <td id="T_76082_row5_col3" class="data row5 col3" >15,668 distinct values</td>
#       <td id="T_76082_row5_col4" class="data row5 col4" ><img src = "......"></img></td>
#       <td id="T_76082_row5_col5" class="data row5 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_76082_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_76082_row6_col1" class="data row6 col1" ><strong>lat</strong><br>[float64]</td>
#       <td id="T_76082_row6_col2" class="data row6 col2" >Mean (sd) : 41.0 (0.1)<br>min < med < max:<br>40.8 < 41.0 < 41.4<br>IQR (CV) : 0.1 (481.7)</td>
#       <td id="T_76082_row6_col3" class="data row6 col3" >8,827 distinct values</td>
#       <td id="T_76082_row6_col4" class="data row6 col4" ><img src = "......"></img></td>
#       <td id="T_76082_row6_col5" class="data row6 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_76082_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_76082_row7_col1" class="data row7 col1" ><strong>id</strong><br>[object]</td>
#       <td id="T_76082_row7_col2" class="data row7 col2" >1. 151347398<br>2. 151347487<br>3. 151346921<br>4. 151346922<br>5. 151349178<br>6. 151349034<br>7. 151349209<br>8. 151346895<br>9. 151349573<br>10. 151349139<br>11. other</td>
#       <td id="T_76082_row7_col3" class="data row7 col3" >16 (0.1%)<br>16 (0.1%)<br>15 (0.1%)<br>15 (0.1%)<br>15 (0.1%)<br>14 (0.1%)<br>14 (0.1%)<br>14 (0.1%)<br>14 (0.1%)<br>14 (0.1%)<br>21,314

# %%
df.to_csv('istanbul_assembly_zones.csv')

# %%
len
